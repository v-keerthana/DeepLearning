# %% [markdown]
# <a href="https://colab.research.google.com/github/v-keerthana/DeepLearning/blob/main/New_Tb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# Out:
#      <input type="file" id="files-6b26148b-d4ae-4fd2-9d24-47c2cd41dc19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b26148b-d4ae-4fd2-9d24-47c2cd41dc19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                               size  lastUpdated          downloadCount
# ----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# yamqwe/omicron-covid19-variant-daily-cases                  Omicron daily cases by country (COVID-19 variant)  432KB  2022-01-24 07:15:53           7903
# nkitgupta/jigsaw-regression-based-data                      Jigsaw Regression Based Data                         3GB  2022-01-10 06:29:59            459
# prasertk/netflix-subscription-price-in-different-countries  Netflix subscription fee in different countries      3KB  2022-01-15 07:06:09            755
# yasserh/song-popularity-dataset                             Song Popularity Dataset                            805KB  2022-01-07 13:18:43           1104
# vishalmane10/anime-dataset-2022                             Anime DataSet 2022                                   5MB  2022-01-16 13:56:16            418
# yasserh/wine-quality-dataset                                Wine Quality Dataset                                21KB  2022-01-15 19:15:11            736
# carlmcbrideellis/gdp-20152019-finland-norway-and-sweden     GDP 2015-2019: Finland, Norway, and Sweden          365B  2022-01-05 07:48:49            401
# yasserh/uber-fares-dataset                                  Uber Fares Dataset                                   7MB  2022-01-01 15:54:14            913
# dansbecker/melbourne-housing-snapshot                       Melbourne Housing Snapshot                         451KB  2018-06-05 12:52:24          79271
# iamsouravbanerjee/analytics-industry-salaries-2022-india    Data Professionals Salary - 2022                    56KB  2022-01-20 13:24:41            835
# fedesoriano/stellar-classification-dataset-sdss17           Stellar Classification Dataset - SDSS17              7MB  2022-01-15 17:11:30            230
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                  201MB  2019-06-03 00:56:47         164137
# zynicide/wine-reviews                                       Wine Reviews                                        51MB  2017-11-27 17:08:04         153069
# residentmario/ramen-ratings                                 Ramen Ratings                                       40KB  2018-01-11 16:04:39          32132
# datasnaek/chess                                             Chess Game Dataset (Lichess)                         3MB  2017-09-04 03:09:09          27206
# jpmiller/publicassistance                                   US Public Food Assistance                          703KB  2020-08-21 16:51:18          15379
# rtatman/188-million-us-wildfires                            1.88 Million US Wildfires                          168MB  2020-05-12 21:03:49          18659
# nasa/kepler-exoplanet-search-results                        Kepler Exoplanet Search Results                      1MB  2017-10-10 18:26:59           9791
# residentmario/things-on-reddit                              Things on Reddit                                    16MB  2017-10-26 14:10:15           8032
# nolanbconaway/pitchfork-data                                18,393 Pitchfork Reviews                            33MB  2017-01-13 04:18:10           9922

# %%
# !kaggle datasets download -d jtiptj/chest-xray-pneumoniacovid19tuberculosis
# Out:
# Downloading chest-xray-pneumoniacovid19tuberculosis.zip to /content
# 100% 1.73G/1.74G [00:23<00:00, 63.4MB/s]
# 100% 1.74G/1.74G [00:23<00:00, 79.8MB/s]

# %%
import zipfile
zf = "/content/chest-xray-pneumoniacovid19tuberculosis.zip"
target_dir = "/content/dataset/chest-xray"
zfile = zipfile.ZipFile(zf)
zfile.extractall(target_dir)

# %%
import os
import shutil
import numpy as np
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.python.keras.layers import Dense,Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout
from keras.models import Model
# from keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import ResNet50 
from keras.preprocessing import image
from keras.models import Sequential
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
import keras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import ImageFile

# %%
train_normal = os.listdir('/content/dataset/chest-xray/train/NORMAL')
train_Tb = os.listdir('/content/dataset/chest-xray/train/TURBERCULOSIS')
print(train_normal[1])
print(train_Tb[1])
# Out:
# NORMAL2-IM-1142-0001-0001.jpeg
# Tuberculosis-143.png

# %%
img = image.load_img('/content/dataset/chest-xray/test/NORMAL/IM-0001-0001.jpeg')

img = image.img_to_array(img)

img =img /255.0
plt.imshow(img)
plt.show()

# %%
def show_imgs(num_of_imgs):
  for i in range(num_of_imgs):
    tb_pic = '/content/dataset/chest-xray/train/TURBERCULOSIS/'+train_Tb[i]

    normal_pic = '/content/dataset/chest-xray/train/NORMAL/'+train_normal[i]

    tb_pic = image.load_img(tb_pic)

    normal_pic = image.load_img(normal_pic)

    tb_pic = image.img_to_array(tb_pic)

    tb_pic =tb_pic /255.0

    normal_pic = image.img_to_array(normal_pic)

    normal_pic =normal_pic /255.0

    fig=plt.figure(figsize=(7,7))

    normal_plot = fig.add_subplot(1,2,1)
    plt.imshow(normal_pic,cmap='gray')
    normal_plot.set_title('Normal')
    plt.axis('off')

    Tb_plot = fig.add_subplot(1,2,2)
    plt.imshow(tb_pic,cmap='gray')
    normal_plot.set_title('Tb')
    plt.axis('off')

    plt.show()

# %%
show_imgs(3)

# %%
s=32
IMAGE_SIZE = [224, 224]

# %%
train_gen = ImageDataGenerator(rescale=1.0/255,
    rotation_range = 40,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    shear_range = 0.2,
    zoom_range = 0.3,
    horizontal_flip = True
    )
val_gen = ImageDataGenerator(rescale=1.0/255)

# %%
# os.remove('/content/dataset/chest-xray/train/COVID19')
os.mkdir('trash')

# %%
# !ls
# Out:
# chest-xray-pneumoniacovid19tuberculosis.zip  kaggle.json  trash
# dataset					     sample_data

# %%
os.listdir('/content/dataset/chest-xray/test')
# Out:
# ['NORMAL', 'COVID19', 'TURBERCULOSIS', 'PNEUMONIA']

# %%
import os
import shutil
import numpy as np
def make_dirs_for_data():
  # path='/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/Tuberculosis'
  # os.listdir(path)[1]

  # par_dir="/content/trash"
  # path = par_dir+'/test'
  # os.mkdir(path)

  # path=par_dir+'/validation'
  # os.mkdir(path)

  # path=par_dir+'/train'
  # os.mkdir(path)

  # path_of_train = "/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train" 
  # path_of_train_normal = path_of_train+'/Normal'
  # path_of_train_Tb = path_of_train+'/Tb'

  # os.mkdir(path_of_train_normal)
  # os.mkdir(path_of_train_Tb)

  # path_of_test = "/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/test"
  # path_of_test_normal = path_of_test+'/Normal'
  # path_of_test_Tb = path_of_test+'/Tb'

  # os.mkdir(path_of_test_normal)
  # os.mkdir(path_of_test_Tb)

  # path_of_val = "/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/validation"
  # path_of_val_normal = path_of_val+'/Normal'
  # path_of_val_Tb = path_of_val+'/Tb'

  # os.mkdir(path_of_val_normal)
  # os.mkdir(path_of_val_Tb)

  source ='/content/dataset/chest-xray/test/'
  destination = '/content/trash/'
  allfiles = os.listdir(source)
  for f in allfiles:
    if(f=='COVID19' or f=='PNEUMONIA'):
      shutil.move(source + f, destination + f)

  source ='/content/dataset/chest-xray/train/'
  destination = '/content/trash/'
  allfiles = os.listdir(source)
  for f in allfiles:
    if(f=='COVID19' or f=='PNEUMONIA'):
      shutil.move(source + f, destination + f +'a')

  source ='/content/dataset/chest-xray/val/'
  destination = '/content/trash/'
  allfiles = os.listdir(source)
  for f in allfiles:
    if(f=='COVID19' or f=='PNEUMONIA'):
      shutil.move(source + f, destination + f + 'b')

  # source = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/Tuberculosis/'
  # destination = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Tb/'
  # allfiles = os.listdir(source)
  # for f in allfiles:
  #   shutil.move(source + f, destination + f)

  # source = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Normal/'
  # destination = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/test/Noraml/'
  # source ='/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Normal/'
  # destination = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/test/Normal/'
  # allfiles = os.listdir(source)
  # np.random.shuffle(allfiles)
  # allfiles = allfiles[:50]
  # for f in allfiles:
  #   shutil.move(source + f, destination + f)

  # source = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Normal/'
  # destination = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/validation/Normal/'
  # allfiles = os.listdir(source)
  # np.random.shuffle(allfiles)
  # allfiles = allfiles[:50]
  # for f in allfiles:
  #   shutil.move(source + f, destination + f)


  # source = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Tb/'
  # destination = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/validation/Tb/'
  # allfiles = os.listdir(source)
  # np.random.shuffle(allfiles)
  # allfiles = allfiles[:50]
  # for f in allfiles:
  #   shutil.move(source + f, destination + f)

  # source = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Tb/'
  # destination = '/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/test/Tb/'
  # allfiles = os.listdir(source)
  # np.random.shuffle(allfiles)
  # allfiles = allfiles[:50]
  # for f in allfiles:
  #   shutil.move(source + f, destination + f)

  # print("test-normal",len(os.listdir('/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/test/Normal')))
  # print("val-normal",len(os.listdir('/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/validation/Normal')))
  # print("train-normal",len(os.listdir("/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Normal")))

  # print("test-Tb",len(os.listdir('/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/test/Tb')))
  # print("val-Tb",len(os.listdir('/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/validation/Tb')))
  # print("train-Tb",len(os.listdir("/content/dataset/cnn/chest-xray/TB_Chest_Radiography_Database/train/Tb")))

# %%
# make_dirs_for_data()

# %%
train_generator = train_gen.flow_from_directory(
    '/content/dataset/chest-xray/train/',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary'
)
val_generator = val_gen.flow_from_directory(
    "/content/dataset/chest-xray/val/",
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 1991 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
train_generator.image_shape
# Out:
# (224, 224, 3)

# %%
train_generator.class_indices
# Out:
# {'NORMAL': 0, 'TURBERCULOSIS': 1}

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, 
                                     Dense, Dropout, BatchNormalization)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import regularizers

from tensorflow.keras.applications import ResNet50
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5',
                              monitor='val_loss',
                             verbose=1, 
                             save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
model = Sequential()

model.add(ResNet50(include_top=False,input_tensor=None,input_shape=(224,224,3),pooling='avg',classes=2))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(1, activation='sigmoid'))

model.layers[0].trainable = False
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_8 (Dense)             (None, 1024)              2098176
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  batch_normalization_6 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  batch_normalization_8 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 26,349,441
# Trainable params: 2,758,145
# Non-trainable params: 23,591,296
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001),loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5',
                              monitor='val_loss',
                             verbose=1, 
                             save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
# Train model
batch_size=64
epochs=15
# History = model.fit_generator(datagen.flow(x_train,y_train,batch_size=batch_size),validation_data=(x_val,y_val),
#                               epochs= epochs, steps_per_epoch=x_train.shape[0]//batch_size,verbose=1,callbacks=[red_lr]
#                              )
#1991/15
History = model.fit_generator(train_generator  ,
                              validation_data=val_generator,
                              epochs= epochs, 
                              steps_per_epoch=30,
                              verbose=1,
                              callbacks=my_callbacks)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/15
# 30/30 [==============================] - ETA: 0s - loss: 0.8603 - accuracy: 0.5333
# Epoch 00001: val_loss improved from inf to 1.26065, saving model to model.01-1.26.h5
# 30/30 [==============================] - 37s 1s/step - loss: 0.8603 - accuracy: 0.5333 - val_loss: 1.2607 - val_accuracy: 0.4000
# Epoch 2/15
# 30/30 [==============================] - ETA: 0s - loss: 0.7888 - accuracy: 0.5797
# Epoch 00002: val_loss improved from 1.26065 to 1.01215, saving model to model.02-1.01.h5
# 30/30 [==============================] - 30s 996ms/step - loss: 0.7888 - accuracy: 0.5797 - val_loss: 1.0122 - val_accuracy: 0.4000
# Epoch 3/15
# 30/30 [==============================] - ETA: 0s - loss: 0.7249 - accuracy: 0.6182
# Epoch 00003: val_loss improved from 1.01215 to 0.79001, saving model to model.03-0.79.h5
# 30/30 [==============================] - 32s 1s/step - loss: 0.7249 - accuracy: 0.6182 - val_loss: 0.7900 - val_accuracy: 0.4000
# Epoch 4/15
# 30/30 [==============================] - ETA: 0s - loss: 0.7267 - accuracy: 0.6208
# Epoch 00004: val_loss improved from 0.79001 to 0.66101, saving model to model.04-0.66.h5
# 30/30 [==============================] - 31s 1s/step - loss: 0.7267 - accuracy: 0.6208 - val_loss: 0.6610 - val_accuracy: 0.6500
# Epoch 5/15
# 30/30 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.6490
# Epoch 00005: val_loss did not improve from 0.66101
# 30/30 [==============================] - 30s 997ms/step - loss: 0.6933 - accuracy: 0.6490 - val_loss: 0.6686 - val_accuracy: 0.6000
# Epoch 6/15
# 30/30 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.6449
# Epoch 00006: val_loss improved from 0.66101 to 0.65518, saving model to model.06-0.66.h5
# 30/30 [==============================] - 30s 988ms/step - loss: 0.7092 - accuracy: 0.6449 - val_loss: 0.6552 - val_accuracy: 0.6000
# Epoch 7/15
# 30/30 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.6229
# Epoch 00007: val_loss did not improve from 0.65518
# 30/30 [==============================] - 30s 986ms/step - loss: 0.6744 - accuracy: 0.6229 - val_loss: 0.6576 - val_accuracy: 0.6000
# Epoch 8/15
# 30/30 [==============================] - ETA: 0s - loss: 0.6458 - accuracy: 0.6545
# Epoch 00008: val_loss did not improve from 0.65518
# 30/30 [==============================] - 29s 967ms/step - loss: 0.6458 - accuracy: 0.6545 - val_loss: 0.6979 - val_accuracy: 0.6000

# %%
plt.style.use("seaborn-dark")
plt.title("Accuracy")
plt.plot(History.history['accuracy'],label="accuracy",c='green')
plt.plot(History.history['val_accuracy'],label="val_accuracy",c='orange')
plt.legend()
plt.show()

# %%
plt.style.use("seaborn-dark")
plt.title("Loss")
plt.plot(History.history['loss'],label="loss",c='green')
plt.plot(History.history['val_loss'],label="val_loss",c='orange')
plt.legend()
plt.show()

# %%
LOG_DIR = '/log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
model = keras.models.load_model(filepath='/content/model.01-0.77.h5')
